# %% [markdown]
# # Credit Card Retention Analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objs as go
from plotly.offline import iplot
sns.set()
pd.options.display.max_columns = 999

# %%
data = pd.read_csv('../data/BankChurners_v2.csv')

# %%
data = data[['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',]]

# %%
data['Education_Level'] = data['Education_Level'].fillna('Unknown')
data['Marital_Status'] = data['Marital_Status'].fillna('Unknown')
data['Income_Category'] = data['Income_Category'].fillna('Unknown')

# %% [markdown]
# ***

# %% [markdown]
# ## Data Transformation: Binning

# %% [markdown]
# To bin our ages, we will need a couple data points: the min and max ages. Let's find those.

# %%
print(data['Customer_Age'].min())
print(data['Customer_Age'].max())
# Out:
# 26
# 73

# %% [markdown]
# For more information, see the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html).

# %%
bins = [25, 30, 40, 50, 60, 70, 80]
labels = ['20s', '30s', '40s', '50s', '60s', '70s']
data['Customer_Age_bins'] = pd.cut(data['Customer_Age'], 
  bins=bins, labels=labels,
  include_lowest=True, right=False)

# %%
data[data['Customer_Age']==35]
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 13        90045  Existing Customer            35      M                3
# 304       90336  Existing Customer            35      M                3
# 463       90495  Attrited Customer            35      M                3
# 605       90637  Existing Customer            35      F                1
# 651       90683  Existing Customer            35      M                3
# ...         ...                ...           ...    ...              ...
# 9680      99712  Attrited Customer            35      F                0
# 9810      99842  Existing Customer            35      M                2
# 9843      99875  Existing Customer            35      M                3
# 9911      99943  Existing Customer            35      M                3
# 9937      99969  Existing Customer            35      F                2
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 13          Graduate        Unknown     $60K - $80K          Blue
# 304       Uneducated        Married     $60K - $80K          Blue
# 463    Post-Graduate        Unknown    $80K - $120K          Blue
# 605          College         Single         Unknown          Blue
# 651         Graduate         Single    $80K - $120K          Blue
# ...              ...            ...             ...           ...
# 9680       Doctorate        Married  Less than $40K          Blue
# 9810        Graduate        Married    $80K - $120K          Blue
# 9843      Uneducated         Single  Less than $40K          Blue
# 9911        Graduate        Married     $60K - $80K          Blue
# 9937        Graduate        Married  Less than $40K          Blue
#
#       Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 13                30                         5                       1
# 304               22                         5                       2
# 463               29                         2                       1
# 605               28                         4                       5
# 651               24                         4                       1
# ...              ...                       ...                     ...
# 9680              27                         2                       3
# 9810              21                         6                       2
# 9843              21                         5                       2
# 9911              36                         4                       1
# 9937              28                         6                       1
#
#       Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# 13                        3        8547.0                 1666
# 304                       2        6985.0                 1130
# 463                       3       17030.0                 1911
# 605                       2        3518.0                 1575
# 651                       2       23561.0                  864
# ...                     ...           ...                  ...
# 9680                      2        3876.0                    0
# 9810                      1        7685.0                 2517
# 9843                      1        6104.0                 1595
# 9911                      4       19671.0                  924
# 9937                      3        4014.0                 2266
#
#       Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 13             6881.0                 1.163             1311              33
# 304            5855.0                 0.963             1694              44
# 463           15119.0                 0.528              715              25
# 605            1943.0                 0.625             2121              60
# 651           22697.0                 1.373             2447              64
# ...               ...                   ...              ...             ...
# 9680           3876.0                 0.848             7712              73
# 9810           5168.0                 0.745            13604             116
# 9843           4509.0                 0.619            15240             102
# 9911          18747.0                 0.820            13908             124
# 9937           1748.0                 0.718            14257              94
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio Customer_Age_bins
# 13                  2.000                  0.195               30s
# 304                 0.760                  0.162               30s
# 463                 0.562                  0.112               30s
# 605                 0.579                  0.448               30s
# 651                 1.000                  0.037               30s
# ...                   ...                    ...               ...
# 9680                0.825                  0.000               30s
# 9810                0.731                  0.328               30s
# 9843                0.729                  0.261               30s
# 9911                0.676                  0.047               30s
# 9937                0.958                  0.565               30s
#
# [184 rows x 22 columns]
